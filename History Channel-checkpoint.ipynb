# %%
import bs4 as bs
import urllib
import urllib.request

# %%
historyurl = 'http://www.history.com/this-day-in-history'
historypage = urllib.request.urlopen(historyurl)
soup = bs.BeautifulSoup(historypage, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <!--[if IE 8 ]>    <html class="ie8"> <![endif]-->
# <!--[if gt IE 8]><!--><html><!--<![endif]-->
# <head>
# <title>This Day in History - What Happened Today - HISTORY.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Learn what happened today in history around the world including major events on crime, entertainment, and more." name="description"/>
# <meta content="Nelson Mandela, nelson Mandela release, release of Nelson Mandela, apartheid, African national congress, ANC, Johannesburg, Robben Island Prison, De Klerk, Nobel peace prize" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# ...

# %%
import datetime
now=datetime.datetime.now()
print=(soup.title.text, now)

# %%
cat=1
for category in soup.findALL('div',{'class':'category'}):
print(cat)
print(category.text)
cat=cat+1
# Out:
#   File "<ipython-input-41-12d750afc215>", line 3
#     print(cat)
#         ^
# IndentationError: expected an indented block

# %%
soup.findALL('div',{'class':'category'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-db39838849f5> in <module>()
# ----> 1 soup.findALL('div',{'class':'category'})
#
# TypeError: 'NoneType' object is not callable

# %%
q = 1
for title in soup.find ('div',{'class':'day articles'}).findALL('p'):
print (q)
q = q+1
print (title)
# Out:
#   File "<ipython-input-39-102a0c674fc5>", line 3
#     print (q)
#         ^
# IndentationError: expected an indented block
